# %%
import pandas as pd

# %%
df_a = pd.DataFrame({'Name':['Harry Potter','David Baker', 'John Smith', 'Juan Martinez','Jane Connor'],
                     'Gender':['Male','Male','Male','Male','Female'],
                     'Age':[23,31,22,36,30]})
df_a
# Out:
#             Name  Gender  Age
# 0   Harry Potter    Male   23
# 1    David Baker    Male   31
# 2     John Smith    Male   22
# 3  Juan Martinez    Male   36
# 4    Jane Connor  Female   30

# %%
df_b = pd.DataFrame({'Name':['Harry Potter','Alex Du Bois', 'Joanne Rowling','Jane Connor'],
                     'Position':['Intern','Team Lead','Manager','Manager'],
                     'Wage':[25000,75000,90000,70000]})
df_b
# Out:
#              Name   Position   Wage
# 0    Harry Potter     Intern  25000
# 1    Alex Du Bois  Team Lead  75000
# 2  Joanne Rowling    Manager  90000
# 3     Jane Connor    Manager  70000

# %%
# Merging DataFrames : A.name B.name used as key
# inner join 
# Inner join is the most common type of join you’ll be working with. It returns a dataframe with only those rows that have common characteristics.
df_a.merge(df_b, left_on='Name', right_on='Name')
# Out:
#            Name  Gender  Age Position   Wage
# 0  Harry Potter    Male   23   Intern  25000
# 1   Jane Connor  Female   30  Manager  70000

# %%
df_a.merge(df_b, how='inner')
# Out:
#            Name  Gender  Age Position   Wage
# 0  Harry Potter    Male   23   Intern  25000
# 1   Jane Connor  Female   30  Manager  70000

# %%
#left join
df_a.merge(df_b, how='left')
# Out:
#             Name  Gender  Age Position     Wage
# 0   Harry Potter    Male   23   Intern  25000.0
# 1    David Baker    Male   31      NaN      NaN
# 2     John Smith    Male   22      NaN      NaN
# 3  Juan Martinez    Male   36      NaN      NaN
# 4    Jane Connor  Female   30  Manager  70000.0

# %%
#right join
df_a.merge(df_b, how='right')
# Out:
#              Name  Gender   Age   Position   Wage
# 0    Harry Potter    Male  23.0     Intern  25000
# 1    Alex Du Bois     NaN   NaN  Team Lead  75000
# 2  Joanne Rowling     NaN   NaN    Manager  90000
# 3     Jane Connor  Female  30.0    Manager  70000

# %%
# Full outer join
#Full Join, also known as Full Outer Join, returns all those records which either have a match in the left or right dataframe.
df_a.merge(df_b, how='outer')
# Out:
#              Name  Gender   Age   Position     Wage
# 0    Harry Potter    Male  23.0     Intern  25000.0
# 1     David Baker    Male  31.0        NaN      NaN
# 2      John Smith    Male  22.0        NaN      NaN
# 3   Juan Martinez    Male  36.0        NaN      NaN
# 4     Jane Connor  Female  30.0    Manager  70000.0
# 5    Alex Du Bois     NaN   NaN  Team Lead  75000.0
# 6  Joanne Rowling     NaN   NaN    Manager  90000.0

# %%
# concat df_A and df_B VERTICALLY
pd.concat([df_a,df_b])
# Out:
#              Name  Gender   Age   Position     Wage
# 0    Harry Potter    Male  23.0        NaN      NaN
# 1     David Baker    Male  31.0        NaN      NaN
# 2      John Smith    Male  22.0        NaN      NaN
# 3   Juan Martinez    Male  36.0        NaN      NaN
# 4     Jane Connor  Female  30.0        NaN      NaN
# 0    Harry Potter     NaN   NaN     Intern  25000.0
# 1    Alex Du Bois     NaN   NaN  Team Lead  75000.0
# 2  Joanne Rowling     NaN   NaN    Manager  90000.0
# 3     Jane Connor     NaN   NaN    Manager  70000.0

# %%
# concat df_A and df_B HORIZONTALLY
pd.concat([df_a,df_b], axis=1)
# Out:
#             Name  Gender  Age            Name   Position     Wage
# 0   Harry Potter    Male   23    Harry Potter     Intern  25000.0
# 1    David Baker    Male   31    Alex Du Bois  Team Lead  75000.0
# 2     John Smith    Male   22  Joanne Rowling    Manager  90000.0
# 3  Juan Martinez    Male   36     Jane Connor    Manager  70000.0
# 4    Jane Connor  Female   30             NaN        NaN      NaN

# %%
df1 = pd.DataFrame({'a':['a0','a1','a2','a3'],
                     'b':['b0','b1','b2','b3'],
                     'c':['c0','c1','c2','c3']},
                      index=[0,1,2,3])
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2 = pd.DataFrame({'a':['a2','a3','a4','a5'],
                    'b':['b2','b3','b4','b5'],
                    'c':['c2','c3','c4','c5'],
                    'd':['d2','d3','d4','d5']},
                      index=[2,3,4,5])
df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
# concat df1, df2

pd.concat([df_a,df_b])
# Out:
#              Name  Gender   Age   Position     Wage
# 0    Harry Potter    Male  23.0        NaN      NaN
# 1     David Baker    Male  31.0        NaN      NaN
# 2      John Smith    Male  22.0        NaN      NaN
# 3   Juan Martinez    Male  36.0        NaN      NaN
# 4     Jane Connor  Female  30.0        NaN      NaN
# 0    Harry Potter     NaN   NaN     Intern  25000.0
# 1    Alex Du Bois     NaN   NaN  Team Lead  75000.0
# 2  Joanne Rowling     NaN   NaN    Manager  90000.0
# 3     Jane Connor     NaN   NaN    Manager  70000.0

# %%
# concat df1, df2, use the parameter 'ignore_index'
pd.concat([df_a,df_b],  ignore_index=True)
# Out:
#              Name  Gender   Age   Position     Wage
# 0    Harry Potter    Male  23.0        NaN      NaN
# 1     David Baker    Male  31.0        NaN      NaN
# 2      John Smith    Male  22.0        NaN      NaN
# 3   Juan Martinez    Male  36.0        NaN      NaN
# 4     Jane Connor  Female  30.0        NaN      NaN
# 5    Harry Potter     NaN   NaN     Intern  25000.0
# 6    Alex Du Bois     NaN   NaN  Team Lead  75000.0
# 7  Joanne Rowling     NaN   NaN    Manager  90000.0
# 8     Jane Connor     NaN   NaN    Manager  70000.0

# %%
# concat df1, df2, use the parameter 'axis=1'
pd.concat([df_a,df_b], axis=1)
# Out:
#             Name  Gender  Age            Name   Position     Wage
# 0   Harry Potter    Male   23    Harry Potter     Intern  25000.0
# 1    David Baker    Male   31    Alex Du Bois  Team Lead  75000.0
# 2     John Smith    Male   22  Joanne Rowling    Manager  90000.0
# 3  Juan Martinez    Male   36     Jane Connor    Manager  70000.0
# 4    Jane Connor  Female   30             NaN        NaN      NaN

# %% [markdown]
# ## DataFrame Sorting and Multi-Index

# %% [markdown]
# ### Sorting

# %%
# read data_studentlist.csv
df=pd.read_csv("./data/data_studentlist.csv")

# %%
# sort it by 'bloodtype'
df.sort_values(by='bloodtype')
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# ...

# %%
# sort it by 'bloodtype' in ascending order 
df.sort_values(by='bloodtype',ascending=True)
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# ...

# %%
# sort it by 'bloodtype' and 'gender'
df.sort_values(by=['bloodtype', 'gender'])
# Out:
#                 name gender  age  grade absence bloodtype  height  weight
# 4    Clara Rodriquez      F   20      1       Y         A   168.0    49.5
# 7    Margareth Jones      F   23      1       N         A   176.9    55.0
# 12      Eddy Johnson      M   21      1       N         A   162.2    55.3
# 16       Andrew King      M   21      1       N         A   169.2    62.2
# 1     Sarah O'Donnel      F   22      2       N        AB   170.1    53.0
# 3       David Hassel      M   23      3       N        AB   182.1    85.7
# 11      John Matsuda      M   22      2       N        AB   180.0    75.8
# 14      Linda Carter      F   22      2       N         B   158.2    45.2
# 2       Brian Martin      M   24      4       N         B   175.0    80.1
# 8       John Bertsch      M   23      3       N         B   178.5    64.2
# 9     Jake Timmerman      M   22      2       N         B   176.1    61.3
# 15    Richard Swayze      M   24      4       Y         B   168.6    70.2
# ...

# %% [markdown]
# # Multi-Indexing

# %%
import numpy as np
my_header = ['a','b','c']
my_index1 = ['G1']*3 +  ['G2']*3
my_index2 = [1,2,3]*3
my_index_list= list(zip(my_index1, my_index2))
my_index = pd.MultiIndex.from_tuples(my_index_list)
df= pd.DataFrame(data=np.random.randn(6,3),index=my_index)

# %%
df
# Out:
#              0         1         2
# G1 1 -0.141203 -1.093808 -0.188846
#    2 -0.764762 -0.073051  0.764377
#    3  0.769557 -0.176522  0.517989
# G2 1  0.309536 -0.841219 -0.626667
#    2  1.154444  0.752343  1.679926
#    3  1.169655 -0.332355  1.846151

# %%
# print the index 
df.index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
# select the first column 
df[0]
# Out:
# G1  1   -0.141203
#     2   -0.764762
#     3    0.769557
# G2  1    0.309536
#     2    1.154444
#     3    1.169655
# Name: 0, dtype: float64

# %%
# select the first column 
df.iloc[:,0]
# Out:
# G1  1   -0.141203
#     2   -0.764762
#     3    0.769557
# G2  1    0.309536
#     2    1.154444
#     3    1.169655
# Name: 0, dtype: float64

# %%
# select the first row using iloc 
df.iloc[0,]
# Out:
# 0   -0.141203
# 1   -1.093808
# 2   -0.188846
# Name: (G1, 1), dtype: float64
