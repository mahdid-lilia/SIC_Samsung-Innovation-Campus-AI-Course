# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(
  "./data/3_TwoNumOrdered.csv", 
    sep=' '
)

# %%
# check the column
data.columns
# Out:
# Index(['date', 'value'], dtype='object')

# %%
#check type of each column
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1822 entries, 0 to 1821
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1822 non-null   object
#  1   value   1822 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 28.6+ KB

# %%
# tranform the type pf date to datetime pandas (use pd.to_datetime)
data['date']=pd.to_datetime(data['date'])

# %%
# check again
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1822 entries, 0 to 1821
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1822 non-null   datetime64[ns]
#  1   value   1822 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 28.6 KB

# %% [markdown]
# [check](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.year.html)

# %%
# create year/ month/day column
data['year']=data['date'].dt.year
data['month']=data['date'].dt.month
data['day']=data['date'].dt.day
     
data

#hint data['date'].dt.year
# Out:
#            date    value  year  month  day
# 0    2013-04-28   135.98  2013      4   28
# 1    2013-04-29   147.49  2013      4   29
# 2    2013-04-30   146.93  2013      4   30
# 3    2013-05-01   139.89  2013      5    1
# 4    2013-05-02   125.60  2013      5    2
# ...         ...      ...   ...    ...  ...
# 1817 2018-04-19  8298.69  2018      4   19
# 1818 2018-04-20  8880.23  2018      4   20
# 1819 2018-04-21  8997.57  2018      4   21
# 1820 2018-04-22  9001.64  2018      4   22
# 1821 2018-04-23  8958.55  2018      4   23
#
# [1822 rows x 5 columns]

# %%
#check again
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1822 entries, 0 to 1821
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1822 non-null   datetime64[ns]
#  1   value   1822 non-null   float64
#  2   year    1822 non-null   int64
#  3   month   1822 non-null   int64
#  4   day     1822 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 71.3 KB

# %%
# line plot data['date']/ value
import datetime
# 1- create a figure using plt.subplots, fix figsize=(8,6)
import matplotlib.pyplot as plt
# 2-plot 
fig,ax=plt.subplots(figsize=(8,6)) 
ax.plot(data['date'],data['value'])

# %%
# 3- set the x limits of the current axes between  (2015, 1, 26) and  (2017, 2, 1)

# %%
fig,ax=plt.subplots(figsize=(8,6)) 
ax.set_xlim([datetime.date(2015, 1, 26), datetime.date(2017, 2, 1)])
ax.plot(data['date'],data['value'])

# %% [markdown]
# # understand subplots

# %%
#create a 2×3 grid of subplots
fig,ax= plt.subplots(2,3,sharex='col',sharey='row',figsize=(8,6))

# %%
for i in range(2):
    for j in range(3):
        ax[i,j].text(0.5,0.5,str((i,j)),fontsize=18,ha='center')
        
fig

# %%
data = pd.read_csv(
  "data/multivariate.csv", 
    sep=';'
)

# %%
data
# Out:
#                   Country    Pop  Birth rate  Mortality rate  Life expectancy  \
# 0         Channel Islands    166       9.280           9.140           81.269
# 1                 Denmark   5733      10.707           9.620           80.839
# 2                 Estonia   1302      10.698          12.657           77.342
# 3                 Finland   5556      10.672           9.865           81.576
# 4                 Iceland    337      12.836           6.467           83.220
# ..                    ...    ...         ...             ...              ...
# 196          Saudi Arabia    333      18.300           3.500           74.900
# 197  Syrian Arab Republic  19482      21.200           5.500           70.600
# 198                Turkey  81086      15.600           5.800           76.300
# 199  United Arab Emirates   9543       9.900           1.800           77.600
# 200                 Yemen  28758      30.300           6.600           64.600
#
#      Infant mortality  Children per woman  Growth rate  Population aged 65+  \
# 0               7.276               1.492         4.56                   30
# 1               3.495               1.758         3.67                 1132
# 2               2.843               1.657        -2.63                  256
# 3               1.839               1.764         2.65                 1212
# 4               1.752               1.893         7.83                   50
# ..                ...                 ...          ...                  ...
# 196            13.100               2.570        16.50                 1099
# 197            14.800               2.750        33.10                  848
# 198             9.700               2.000         7.80                 6672
# 199             5.200               1.720        15.20                  144
# 200            48.100               3.730        22.20                  870
#
#      Group Continent
# 0    North    Europe
# 1    North    Europe
# 2    North    Europe
# 3    North    Europe
# 4    North    Europe
# ..     ...       ...
# 196   West      Asia
# 197   West      Asia
# 198   West      Asia
# 199   West      Asia
# 200   West      Asia
#
# [201 rows x 11 columns]

# %%
# plot the distribution of Birth rate and Mortality rate in the same plot 
import seaborn as sns
sns.set_color_codes() 
sns.distplot(data['Birth rate'])
sns.distplot(data['Mortality rate'])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Mortality rate', ylabel='Density'>

# %%
sns.distplot(data['Mortality rate'],kde=True, hist=False)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Mortality rate', ylabel='Density'>

# %%
# print the correlation matrix 
mat=data.corr()
mat
# Out:
#                           Pop  Birth rate  Mortality rate  Life expectancy  \
# Pop                  1.000000   -0.042879       -0.005079        -0.006034
# Birth rate          -0.042879    1.000000       -0.043080        -0.839977
# Mortality rate      -0.005079   -0.043080        1.000000        -0.294270
# Life expectancy     -0.006034   -0.839977       -0.294270         1.000000
# Infant mortality     0.013773    0.877932        0.196863        -0.925539
# Children per woman  -0.046170    0.977673        0.008703        -0.784815
# Growth rate         -0.032978    0.899490       -0.313049        -0.656512
# Population aged 65+  0.751681   -0.133978        0.049057         0.079067
#
#                      Infant mortality  Children per woman  Growth rate  \
# Pop                          0.013773           -0.046170    -0.032978
# Birth rate                   0.877932            0.977673     0.899490
# Mortality rate               0.196863            0.008703    -0.313049
# Life expectancy             -0.925539           -0.784815    -0.656512
# Infant mortality             1.000000            0.843144     0.730304
# Children per woman           0.843144            1.000000     0.872341
# Growth rate                  0.730304            0.872341     1.000000
# Population aged 65+         -0.072616           -0.131308    -0.117647
#
#                      Population aged 65+
# Pop                             0.751681
# Birth rate                     -0.133978
# Mortality rate                  0.049057
# Life expectancy                 0.079067
# Infant mortality               -0.072616
# Children per woman             -0.131308
# Growth rate                    -0.117647
# Population aged 65+             1.000000

# %%
# plot the heatmap using the correlationn matrix
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# using pivot_table , average,min,max( morality_rate, birth_rate ) for each continent  , comments 
import numpy as np
table = pd.pivot_table(data, values=['Mortality rate', 'Birth rate'], index=['Continent'],
                      aggfunc=[np.mean,np.min, np.max])
table
# Out:
#                     mean                      amin                      amax  \
#               Birth rate Mortality rate Birth rate Mortality rate Birth rate
# Continent
# Africa         31.354386       8.500000       10.8          2.400       48.4
# Asia           18.131373       6.054902        7.5          1.600       35.0
# Europe         10.381300      10.781825        7.5          6.467       13.8
# North America  11.500000       8.000000       10.5          7.500       12.5
# Oceania        20.730769       6.200000       12.8          4.700       27.7
# South America  16.497368       6.884211        9.6          3.000       25.6
#
#
#               Mortality rate
# Continent
# Africa                14.800
# Asia                  11.500
# Europe                16.187
# North America          8.500
# Oceania                7.600
# South America         10.900

# %%
# Average pop and growth_rate  for each group in one code sentence. Use the groupby() method. 
data.groupby('Group')['Pop','Growth rate'].mean()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_21748/45868392.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Group')['Pop','Growth rate'].mean()
#                          Pop  Growth rate
# Group
# AusNZ           14807.000000    10.950000
# Caribean         2569.882353     4.623529
# Central         19535.500000    12.925000
# East            60235.368421    12.394737
# Melanesia        2034.400000    15.160000
# Micronesia        133.333333    11.766667
# Middle          18264.777778    25.777778
# North           16815.444444     8.515556
# North America  182897.000000     8.050000
# Polynesia         199.333333     8.033333
# South           21388.000000     6.646667
# South-Central  135035.714286    13.121429
# South-East      59491.363636    12.327273
# West            18769.756098    16.773171

# %%
# Sort the DataFrame in descending order of the growth_rate
data.sort_values(by=['Growth rate'],ascending=False)
# Out:
#                   Country    Pop  Birth rate  Mortality rate  Life expectancy  \
# 94                  Niger  22445      48.400            8.20            63.10
# 197  Syrian Arab Republic  19482      21.200            5.50            70.60
# 58                 Uganda  43021      41.200            8.50            61.10
# 42                Burundi  12329      41.800           10.40            58.20
# 65                   Chad  15444      43.400           13.10            52.70
# ..                    ...    ...         ...             ...              ...
# 6                  Latvia   1936      10.093           15.36            74.59
# 20                Ukraine   4417      10.600           15.60            71.30
# 192               Lebanon   6022      15.500            4.60            80.40
# 17                Romania  19105       8.900           13.70            75.20
# 12               Bulgaria   6992       9.400           15.60            74.60
#
#      Infant mortality  Children per woman  Growth rate  Population aged 65+  \
# 94             49.500               7.430        40.10                  581
# 197            14.800               2.750        33.10                  848
# 58             55.600               5.410        32.20                 1062
# 42             70.300               5.620        32.00                  319
# 65             85.900               5.740        31.30                  383
# ..                ...                 ...          ...                  ...
# 6               5.493               1.555        -4.36                  383
# 20              8.300               1.560        -5.40                 7283
# 192             7.900               1.710        -6.20                  530
# 17              8.300               1.540        -6.90                 3575
# 12              8.000               1.600        -7.60                 1463
#
#       Group Continent
# 94     West    Africa
# 197    West      Asia
# 58     East    Africa
# 42     East    Africa
# 65   Middle    Africa
# ..      ...       ...
# 6     North    Europe
# 20     East    Europe
# 192    West      Asia
# 17     East    Europe
# 12     East    Europe
#
# [201 rows x 11 columns]

# %%
# get the countries where less than 5
data[data['Growth rate']<5]
# Out:
#                               Country      Pop  Birth rate  Mortality rate  \
# 0                     Channel Islands      166       9.280           9.140
# 1                             Denmark     5733      10.707           9.620
# 2                             Estonia     1302      10.698          12.657
# 3                             Finland     5556      10.672           9.865
# 6                              Latvia     1936      10.093          15.360
# 7                           Lithuania     2817      10.459          16.187
# 11                            Belarus     9429      11.600          14.600
# 12                           Bulgaria     6992       9.400          15.600
# 13                     Czech Republic    10563      10.000          10.600
# 14                            Hungary     9754       9.300          13.500
# 15                             Poland    38523       9.400          10.400
# 16                Republic of Moldova     4045      10.000          11.700
# 17                            Romania    19105       8.900          13.700
# 18                 Russian Federation   143261      12.300          14.200
# 19                           Slovakia     5434      10.300          10.300
# 20                            Ukraine     4417      10.600          15.600
# 21                            Albania     2919      13.800           7.800
# 22             Bosnia and Herzegovina     3782       8.400          11.100
# 23                            Croatia     4195       9.100          12.800
# 24                             Greece    10872       7.900          11.300
# 25                              Italy    59788       8.200          10.300
# 26                              Malta      421       9.000           9.300
# 27                         Montenegro      626      11.000          10.300
# 28                           Portugal    10229       7.500          10.700
# 29                             Serbia     8743      10.200          13.100
# 30                           Slovenia     2073      10.100          10.000
# 31                              Spain    46117       8.500           9.200
# 32                     TFYR Macedonia     2085      11.100           9.800
# 33                            Austria     8614       9.700           9.500
# 35                             France    65206      11.900           9.100
# 36                            Germany    80561       8.700          11.300
# 38                        Netherlands    17085      10.500           8.800
# 50                          Mauritius     1285      10.800           8.000
# 55                         Seychelles       98      15.500           7.700
# 100                             Aruba      105      10.000           9.100
# 102                          Barbados      286      11.800          10.900
# 103                              Cuba    11383       9.600           8.300
# 106                           Grenada      108      18.100           7.100
# 107                        Guadeloupe      474      12.200           7.300
# 109                           Jamaica     2823      16.600           7.100
# 110                        Martinique      396      10.600           9.100
# 111                       Puerto Rico     3678      11.300           8.000
# 113  Saint Vincent and the Grenadines      110      15.000           7.400
# 114               Trinidad and Tobago     1373      12.900           9.900
# 115      United States Virgin Islands      107      12.700           8.200
# 118                       El Salvador     6188      16.800           7.000
# 135                           Uruguay      347      13.800           9.400
# 139                              Fiji      907      18.600           7.300
# 150                             China  1393686      11.300           7.400
# 153                             Korea    25527      14.200           9.500
# 154                             Japan   125738       8.000          11.000
# 156                 Republic of Korea    50897       9.000           6.100
# 157                            Taiwan     2341       7.500           7.500
# 166                          Thailand    68416       9.800           8.400
# 179                         Sri Lanka    20996      14.700           7.100
# 183                           Armenia     3035      12.400           9.600
# 187                           Georgia     3974      12.800          11.500
# 192                           Lebanon     6022      15.500           4.600
#
#      Life expectancy  Infant mortality  Children per woman  Growth rate  \
# 0             81.269             7.276               1.492         4.56
# 1             80.839             3.495               1.758         3.67
# 2             77.342             2.843               1.657        -2.63
# 3             81.576             1.839               1.764         2.65
# 6             74.590             5.493               1.555        -4.36
# 7             73.831             3.076               1.641        -4.27
# 11            71.800             3.500               1.650        -3.30
# 12            74.600             8.000               1.600        -7.60
# 13            79.200             2.100               1.540         0.70
# 14            75.700             4.200               1.410        -3.50
# 15            78.100             4.000               1.330        -1.20
# 16            71.900             9.700               1.230        -2.70
# 17            75.200             8.300               1.540        -6.90
# 18            70.500             7.300               1.730        -1.00
# 19            76.800             4.400               1.440         0.30
# 20            71.300             8.300               1.560        -5.40
# 21            78.500            12.500               1.780         2.70
# 22            77.100             6.400               1.230        -2.90
# 23            78.000             3.200               1.480        -3.70
# 24            81.700             2.300               1.300        -2.00
# 25            83.800             1.900               1.490        -0.20
# 26            81.200             4.000               1.490         2.00
# 27            76.700             3.600               1.650        -0.10
# 28            81.900             2.600               1.240        -3.40
# 29            75.400             8.200               1.600        -3.90
# 30            81.100             2.700               1.660         0.80
# 31            83.300             2.500               1.380         1.10
# 32            76.000             8.400               1.560         0.90
# 33            82.200             2.500               1.530         2.40
# 35            82.900             2.800               1.990         4.10
# 36            81.600             2.500               1.440        -1.00
# 38            82.100             3.000               1.770         3.00
# 50            75.100            10.100               1.430         2.70
# 55            73.800             8.100               2.210         4.60
# 100           76.100            13.600               1.620         2.60
# 102           76.300             7.900               1.800         2.30
# 103           80.100             4.700               1.580        -0.70
# 106           74.000             8.400               2.070         4.80
# 107           82.100             4.600               2.100         3.60
# 109           76.200            13.100               1.980         3.30
# 110           82.700             5.000               1.870        -1.10
# 111           80.300             5.300               1.580        -0.30
# 113           73.400            15.100               1.890         2.70
# 114           70.800            22.700               1.730         2.30
# 115           81.300             8.400               2.170         1.50
# 118           74.000            14.100               1.860         3.50
# 135           77.800            10.900               1.980         3.70
# 139           70.700            13.100               2.470         4.90
# 150           76.600             9.300               1.590         3.70
# 153           71.200            19.000               1.930         4.70
# 154           84.100             1.900               1.470        -2.60
# 156           82.900             2.100               1.340         3.70
# 157           80.400             3.400               1.030         0.10
# 166           75.200             9.300               1.450         1.50
# 179           75.600             6.800               2.020         4.20
# 183           75.400            11.200               1.500         0.90
# 187           75.500            11.500               1.820         0.50
# 192           80.400             7.900               1.710        -6.20
#
#      Population aged 65+          Group      Continent
# 0                     30          North         Europe
# 1                   1132          North         Europe
# 2                    256          North         Europe
# 3                   1212          North         Europe
# 6                    383          North         Europe
# 7                    535          North         Europe
# 11                  1387           East         Europe
# 12                  1463           East         Europe
# 13                  2067           East         Europe
# 14                  1864           East         Europe
# 15                  6686           East         Europe
# 16                   464           East         Europe
# 17                  3575           East         Europe
# 18                 20676           East         Europe
# 19                   837           East         Europe
# 20                  7283           East         Europe
# 21                   393          South         Europe
# 22                   644          South         Europe
# 23                   844          South         Europe
# 24                  2383          South         Europe
# 25                  1397          South         Europe
# 26                    86          South         Europe
# 27                    94          South         Europe
# 28                  2246          South         Europe
# 29                  1626          South         Europe
# 30                   406          South         Europe
# 31                  9048          South         Europe
# 32                   284          South         Europe
# 33                   166           West         Europe
# 35                 13167           West         Europe
# 36                 17746           West         Europe
# 38                   333           West         Europe
# 50                   140           East         Africa
# 55                     7           East         Africa
# 100                   14       Caribean  South America
# 102                   44       Caribean  South America
# 103                 1745       Caribean  South America
# 106                    8       Caribean  South America
# 107                   76       Caribean  South America
# 109                  273       Caribean  South America
# 110                   83       Caribean  South America
# 111                  566       Caribean  South America
# 113                    9       Caribean  South America
# 114                  142       Caribean  South America
# 115                   21       Caribean  South America
# 118                  542        Central  South America
# 135                  512          South  South America
# 139                   58      Melanesia        Oceania
# 150                15442           East           Asia
# 153                 2314           East           Asia
# 154                 3488           East           Asia
# 156                 7395           East           Asia
# 157                 3318           East           Asia
# 166                 8118     South-East           Asia
# 179                 2186  South-Central           Asia
# 183                  356           West           Asia
# 187                  569           West           Asia
# 192                  530           West           Asia
